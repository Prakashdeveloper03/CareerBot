# %% [markdown]
# ## Load Dataset

# %%
import json

# Open and read the JSON file containing intent data
with open("./data/intents.json") as data_file:
    data = data_file.read()

# Parse the JSON data into a Python dictionary
intents = json.loads(data)

# %% [markdown]
# ## Data Preprocessing

# %%
# Import necessary libraries
import nltk
from nltk.stem import WordNetLemmatizer

# Initialize WordNet lemmatizer
lemmatizer = WordNetLemmatizer()

# Download NLTK resources (if not already downloaded)
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Initialize lists to hold words, classes, and document tuples
words = []
classes = []
documents = []

# Define punctuation marks to ignore during processing
ignore_words = ["?", "!"]

# Iterate over intents and their patterns
for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        # Tokenize each word in the pattern
        w = nltk.word_tokenize(pattern)

        # Extend the words list with tokenized words
        words.extend(w)

        # Add documents to the corpus as tuples containing tokenized words and intent tag
        documents.append((w, intent["tag"]))

        # Add the intent tag to the classes list if it's not already present
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %% [markdown]
# ### Lemmatize, Convert to lowercase, and Remove duplicates

# %%
# Lemmatize, convert to lowercase, and remove duplicates from the words list
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# Sort the classes list
classes = sorted(list(set(classes)))

# Print information about the dataset
print(len(documents), "documents")  # Total number of documents (patterns and intents)
print(len(classes), "classes", classes)  # Total number of classes (intents)
print(
    len(words), "unique lemmatized words", words
)  # Total number of unique lemmatized words
# Out:
# 21 documents
# 7 classes ['goodbye', 'greeting', 'java_course_recommendation', 'javascript_course_recommendation', 'options', 'python_course_recommendation', 'thanks']
# 35 unique lemmatized words ['a', 'any', 'appreciate', 'bye', 'can', 'course', 'do', 'find', 'for', 'goodbye', 'have', 'hello', 'help', 'hey', 'hi', 'how', 'i', 'it', 'java', 'javascript', 'later', 'learn', 'offer', 'python', 'see', 'service', 'suggestion', 'thank', 'thanks', 'to', 'tutorial', 'want', 'what', 'where', 'you']

# %% [markdown]
# ### Save words and classes list

# %%
import pickle

# Save processed data to pickle files for future use
with open("./models/words.pkl", "wb") as words_file:
    pickle.dump(words, words_file)  # Save the words list to a pickle file

with open("./models/classes.pkl", "wb") as classes_file:
    pickle.dump(classes, classes_file)  # Save the classes list to a pickle file

# %% [markdown]
# ## Data Splitting

# %%
import random

# Prepare training data
training_data = []

# Iterate over each document (pattern and intent)
for doc in documents:
    # Initialize our bag of words
    bag_of_words = []

    # Get the list of tokenized words for the pattern
    pattern_words = doc[0]

    # Lemmatize each word to its base form
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    # Create the bag of words array
    for word in words:
        bag_of_words.append(1) if word in pattern_words else bag_of_words.append(0)

    # Generate the output row: '0' for each tag and '1' for the current tag
    output_row = [0] * len(classes)
    output_row[classes.index(doc[1])] = 1

    # Add the bag of words and output row to the training data
    training_data.append([bag_of_words, output_row])

# Shuffle the training data
random.shuffle(training_data)

# Create train_x and train_y lists
train_x = [data[0] for data in training_data]  # Features
train_y = [data[1] for data in training_data]  # Labels

# Print a message indicating the completion of training data creation
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Model Building

# %%
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.optimizers import SGD

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4608
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 13319 (52.03 KB)
# Trainable params: 13319 (52.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np

hist = model.fit(
    np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1
)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 9ms/step - loss: 1.9861 - accuracy: 0.0952
# Epoch 2/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1.9915 - accuracy: 0.0476
# Epoch 3/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.9391 - accuracy: 0.1905
# Epoch 4/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.8623 - accuracy: 0.0952
# Epoch 5/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.7874 - accuracy: 0.3810
# Epoch 6/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.8176 - accuracy: 0.3333
# Epoch 7/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.7054 - accuracy: 0.5714
# Epoch 8/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5811 - accuracy: 0.4762
# Epoch 9/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.6175 - accuracy: 0.5714
# Epoch 10/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.5549 - accuracy: 0.5238
# Epoch 11/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.4355 - accuracy: 0.6190
# Epoch 12/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3837 - accuracy: 0.4762
# Epoch 13/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.4118 - accuracy: 0.5714
# Epoch 14/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3054 - accuracy: 0.5714
# Epoch 15/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2837 - accuracy: 0.5238
# Epoch 16/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1.0160 - accuracy: 0.6667
# Epoch 17/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1199 - accuracy: 0.6190
# Epoch 18/200
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1660 - accuracy: 0.7619
# Epoch 19/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9818 - accuracy: 0.6667
# Epoch 20/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9246 - accuracy: 0.7143
# Epoch 21/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9691 - accuracy: 0.6667
# Epoch 22/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7726 - accuracy: 0.7619
# Epoch 23/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6797 - accuracy: 0.9048
# Epoch 24/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5961 - accuracy: 0.9048
# Epoch 25/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7799 - accuracy: 0.8095
# Epoch 26/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7545 - accuracy: 0.8095
# Epoch 27/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8281 - accuracy: 0.7143
# Epoch 28/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5813 - accuracy: 0.9048
# Epoch 29/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5640 - accuracy: 1.0000
# Epoch 30/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4681 - accuracy: 0.8571
# Epoch 31/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5631 - accuracy: 0.8571
# Epoch 32/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4469 - accuracy: 0.9048
# Epoch 33/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.8095
# Epoch 34/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5458 - accuracy: 0.9048
# Epoch 35/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4885 - accuracy: 0.8571
# Epoch 36/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5338 - accuracy: 0.8571
# Epoch 37/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4400 - accuracy: 0.9524
# Epoch 38/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5024 - accuracy: 0.8571
# Epoch 39/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4703 - accuracy: 0.9524
# Epoch 40/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3881 - accuracy: 0.9048
# Epoch 41/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2800 - accuracy: 0.9524
# Epoch 42/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2510 - accuracy: 0.9524
# Epoch 43/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3697 - accuracy: 0.9048
# Epoch 44/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3791 - accuracy: 0.9048
# Epoch 45/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3854 - accuracy: 0.9048
# Epoch 46/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2154 - accuracy: 1.0000
# Epoch 47/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2301 - accuracy: 0.9524
# Epoch 48/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2499 - accuracy: 0.9524
# Epoch 49/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3147 - accuracy: 0.9048
# Epoch 50/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1429 - accuracy: 1.0000
# Epoch 51/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 1.0000
# Epoch 52/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1264 - accuracy: 0.9524
# Epoch 53/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 54/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1801 - accuracy: 0.9524
# Epoch 55/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3182 - accuracy: 0.9524
# Epoch 56/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1869 - accuracy: 1.0000
# Epoch 57/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1293 - accuracy: 0.9524
# Epoch 58/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 1.0000
# Epoch 59/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0963 - accuracy: 1.0000
# Epoch 60/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2668 - accuracy: 0.9048
# Epoch 61/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1235 - accuracy: 1.0000
# Epoch 62/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 1.0000
# Epoch 63/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.9524
# Epoch 64/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1682 - accuracy: 1.0000
# Epoch 65/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1271 - accuracy: 0.9524
# Epoch 66/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1531 - accuracy: 0.9524
# Epoch 67/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.9048
# Epoch 68/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1613 - accuracy: 0.9524
# Epoch 69/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2089 - accuracy: 0.9524
# Epoch 70/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 71/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4560 - accuracy: 0.8095
# Epoch 72/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1271 - accuracy: 0.9524
# Epoch 73/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 74/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 75/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0939 - accuracy: 1.0000
# Epoch 76/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 77/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1705 - accuracy: 0.9524
# Epoch 78/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 1.0000
# Epoch 79/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1150 - accuracy: 1.0000
# Epoch 80/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1819 - accuracy: 0.9048
# Epoch 81/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1287 - accuracy: 0.9524
# Epoch 82/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1266 - accuracy: 0.9524
# Epoch 83/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 84/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0868 - accuracy: 1.0000
# Epoch 85/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1142 - accuracy: 1.0000
# Epoch 86/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 87/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 88/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 89/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 90/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 91/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9524
# Epoch 92/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 1.0000
# Epoch 93/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 94/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 95/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 96/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 97/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 98/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 1.0000
# Epoch 99/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0681 - accuracy: 1.0000
# Epoch 100/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 101/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 102/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 103/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 104/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 105/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 106/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 107/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 108/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0653 - accuracy: 1.0000
# Epoch 109/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 110/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 111/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1003 - accuracy: 0.9524
# Epoch 112/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 113/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 1.0000
# Epoch 114/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 115/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1430 - accuracy: 0.9524
# Epoch 116/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0640 - accuracy: 1.0000
# Epoch 117/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 118/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 119/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 120/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0707 - accuracy: 0.9524
# Epoch 121/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 122/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 123/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 124/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 125/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 126/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0850 - accuracy: 0.9524
# Epoch 127/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0841 - accuracy: 0.9524
# Epoch 128/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 129/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 130/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0930 - accuracy: 1.0000
# Epoch 131/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 132/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 133/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 134/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 135/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 1.0000
# Epoch 136/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 137/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 138/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0878 - accuracy: 0.9524
# Epoch 139/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9524
# Epoch 140/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9524
# Epoch 141/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 142/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 143/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1286 - accuracy: 0.9524
# Epoch 144/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 145/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 146/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 147/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 148/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 149/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 150/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 151/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 152/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 153/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1005 - accuracy: 0.9524
# Epoch 154/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 155/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 156/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.9524
# Epoch 157/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 158/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 159/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 160/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 161/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 162/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.9524
# Epoch 163/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0588 - accuracy: 0.9524
# Epoch 164/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 165/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 166/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 167/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 168/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1668 - accuracy: 0.9524
# Epoch 169/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 170/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 171/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 172/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 173/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 174/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 175/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1369 - accuracy: 0.9524
# Epoch 176/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 177/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 178/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 179/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 180/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 181/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 182/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 183/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 184/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 185/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 1.0000
# Epoch 186/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 187/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 188/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 189/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 190/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 191/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 192/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 193/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0587 - accuracy: 0.9524
# Epoch 194/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 195/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 196/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 197/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 198/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 199/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 200/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000

# %%
model.save("./models/model.keras", hist)

# %%
import random
import nltk
import numpy as np

# Define your functions


def clean_up_sentence(sentence: str) -> list:
    """
    Tokenizes and lemmatizes the input sentence.

    Args:
    sentence (str): Input sentence to be cleaned up.

    Returns:
    list: List of lemmatized words.
    """
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words


def bow(sentence: str, words: list, show_details: bool = True) -> np.array:
    """
    Converts a sentence into a bag of words array.

    Args:
    sentence (str): Input sentence.
    words (list): List of words from the vocabulary.
    show_details (bool): Whether to print details or not.

    Returns:
    np.array: Bag of words array.
    """
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return np.array(bag)


def predict_class(sentence: str, model) -> list:
    """
    Predicts the intent of the input sentence.

    Args:
    sentence (str): Input sentence.
    model: Trained model for prediction.

    Returns:
    list: List of intents with their probabilities.
    """
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list


def get_response(ints: list, intents_json: dict) -> str:
    """
    Retrieves a response based on the predicted intent.

    Args:
    ints (list): List of predicted intents with their probabilities.
    intents_json (dict): JSON object containing intents and responses.

    Returns:
    str: Response message.
    """
    tag = ints[0]["intent"]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result


def chatbot_response(text: str) -> str:
    """
    Generates a response from the chatbot based on the input text.

    Args:
    text (str): Input text from the user.

    Returns:
    str: Response message from the chatbot.
    """
    ints = predict_class(text, model)
    res = get_response(ints, intents)
    return res

# %%
# !pip install -U gradio
import gradio as gr


def chatbot(message, history):
    if message.strip() != "":
        res = chatbot_response(message)
        return res


iface = gr.ChatInterface(
    chatbot,
    chatbot=gr.Chatbot(height=300),
    textbox=gr.Textbox(
        placeholder="Ask me a yes or no question", container=False, scale=7
    ),
    description="Ask questions about Jobs & Courses",
    theme="soft",
    examples=["Do you have any suggestions for a Python course?"],
    cache_examples=True,
    retry_btn=None,
    undo_btn="Delete Previous",
    clear_btn="Clear",
    title="Chat with Bot",
)
iface.launch()
