# %% [markdown]
# ## Import and Load data file

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from keras.models import Sequential
#       3 from keras.layers import Dense, Activation, Dropout
#       4 from keras.optimizers import SGD
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\_tf_keras\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\activations\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.src.activations import deserialize
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\backend\__init__.py:33
#      31 # Import backend functions.
#      32 if backend() == "tensorflow":
# ---> 33     from keras.src.backend.tensorflow import *  # noqa: F403
#      34 elif backend() == "jax":
#      35     from keras.src.backend.jax import *  # noqa: F403
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\backend\tensorflow\__init__.py:1
# ----> 1 from keras.src.backend.tensorflow import core
#       2 from keras.src.backend.tensorflow import distribution_lib
#       3 from keras.src.backend.tensorflow import image
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\backend\tensorflow\core.py:4
#       1 import types
#       3 import numpy as np
# ----> 4 import tensorflow as tf
#       5 from tensorflow.compiler.tf2xla.python.xla import dynamic_update_slice
#       7 from keras.src.backend.common import KerasVariable
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
import json
import pickle


data_file = open("../data/intents.json").read()
intents = json.loads(data_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import pickle
#       7 import numpy as np
# ----> 8 from keras.models import Sequential
#       9 from keras.layers import Dense, Activation, Dropout
#      10 from keras.optimizers import SGD
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\_tf_keras\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\activations\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.src.activations import deserialize
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\backend\__init__.py:33
#      31 # Import backend functions.
#      32 if backend() == "tensorflow":
# ---> 33     from keras.src.backend.tensorflow import *  # noqa: F403
#      34 elif backend() == "jax":
#      35     from keras.src.backend.jax import *  # noqa: F403
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\backend\tensorflow\__init__.py:1
# ----> 1 from keras.src.backend.tensorflow import core
#       2 from keras.src.backend.tensorflow import distribution_lib
#       3 from keras.src.backend.tensorflow import image
#
# File ~\.conda\envs\soa\Lib\site-packages\keras\src\backend\tensorflow\core.py:4
#       1 import types
#       3 import numpy as np
# ----> 4 import tensorflow as tf
#       5 from tensorflow.compiler.tf2xla.python.xla import dynamic_update_slice
#       7 from keras.src.backend.common import KerasVariable
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
for intent in intents["intents"]:
    for pattern in intent["patterns"]:

        # tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)

        # add documents in the corpus
        documents.append((w, intent["tag"]))

        # add to our classes list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %% [markdown]
# lemmatize each word and remove duplicate words from the list

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print(len(documents), "documents")
# classes = intents
print(len(classes), "classes", classes)
# words = all words, vocabulary
print(len(words), "unique lemmatized words", words)

pickle.dump(words, open("../models/words.pkl", "wb"))
pickle.dump(classes, open("../models/classes.pkl", "wb"))
# Out:
# 125 documents
# 43 classes ['age', 'art', 'book_recommendation', 'books', 'compliment', 'current_events', 'dance', 'dreams', 'education', 'environment', 'fashion', 'favorite_color', 'food', 'fun_fact', 'goodbye', 'greeting', 'happiness', 'health', 'help', 'history', 'hobby', 'insult', 'joke', 'math', 'meaning_of_life', 'movie_recommendation', 'movies', 'music', 'music_recommendation', 'name', 'options', 'pets', 'philosophy', 'politics', 'random_fact', 'science', 'sing', 'sports', 'technology', 'thanks', 'time', 'travel', 'weather']
# 144 unique lemmatized words ["'re", "'s", '+', '2', 'a', 'about', 'age', 'any', 'appreciate', 'are', 'art', 'assist', 'assistance', 'athlete', 'awesome', 'background', 'belief', 'book', 'bye', 'can', 'capability', 'color', 'concept', 'created', 'current', 'dance', 'delicious', 'destination', 'did', 'do', 'dream', 'eat', 'education', 'educational', 'emotion', 'environment', 'environmental', 'event', 'existence', 'experience', 'fact', 'famous', 'fashion', 'favorite', 'food', 'for', 'forecast', 'form', 'fun', 'gadget', 'go', 'going', 'good', 'goodbye', 'great', 'happened', 'happening', 'happy', 'hate', 'have', 'health', 'hello', 'help', 'here', 'hey', 'hi', 'historical', 'history', 'hobby', 'how', 'howdy', 'i', 'in', 'is', 'issue', 'it', 'joke', 'know', 'later', 'life', 'like', 'listen', 'math', 'me', 'meaning', 'movie', 'music', 'name', 'named', 'need', 'new', 'of', 'old', 'past', 'pet', 'philosophical', 'philosophy', 'politics', 'popular', 'problem', 'purpose', 'rain', 'random', 'read', 'recipe', 'recommend', 'school', 'science', 'scientific', 'see', 'share', 'should', 'sing', 'solve', 'some', 'song', 'sport', 'stupid', 'tech', 'technology', 'tell', 'terrible', 'thank', 'thanks', 'the', 'time', 'tip', 'to', 'today', 'travel', 'trend', 'trending', 'watch', 'we', 'weather', 'were', 'what', 'when', 'where', 'why', 'with', 'world', 'you', 'your']

# %% [markdown]
# ## Create training and testing data

# %%
# Initialize lists to hold words, classes, and document tuples
words = []
classes = []
documents = []

# Process each intent in the intents dictionary
for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        # Tokenize each word in the pattern
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # Add documents in the corpus
        documents.append((w, intent["tag"]))
        # Add to our classes list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# Lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in "?"]
words = sorted(list(set(words)))

# Sort classes
classes = sorted(list(set(classes)))

# Prepare training data
training = []
# Create an empty array for the output
output_empty = [0] * len(classes)

# Training set, bag of words for each sentence
for doc in documents:
    # Initialize our bag of words
    bag = []
    # List of tokenized words for the pattern
    pattern_words = doc[0]
    # Lemmatize each word - create base word, in an attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # Create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # Output is '0' for each tag and '1' for the current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# Shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training, dtype=object)

# Create train and test lists
train_x = list(training[:, 0])
train_y = list(training[:, 1])

# Optionally convert lists to NumPy arrays
train_x = np.array(train_x)
train_y = np.array(train_y)

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Create Model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])

# fitting and saving the model
hist = model.fit(
    np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1
)
model.save("../models/chatbot_model.h5", hist)

print("model created")
# Out:
# Epoch 1/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.7813 - accuracy: 0.0480
# Epoch 2/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.7325 - accuracy: 0.0640
# Epoch 3/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.6524 - accuracy: 0.1120
# Epoch 4/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.6081 - accuracy: 0.1040
# Epoch 5/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.6035 - accuracy: 0.0880
# Epoch 6/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.5091 - accuracy: 0.1200
# Epoch 7/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.4017 - accuracy: 0.1040
# Epoch 8/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.2723 - accuracy: 0.1760
# Epoch 9/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.2183 - accuracy: 0.1680
# Epoch 10/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.2170 - accuracy: 0.1840
# Epoch 11/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0804 - accuracy: 0.2160
# Epoch 12/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9891 - accuracy: 0.2640
# Epoch 13/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.8120 - accuracy: 0.2640
# Epoch 14/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.7620 - accuracy: 0.2880
# Epoch 15/200
# 25/25 [==============================] - 0s 2ms/step - loss: 2.7049 - accuracy: 0.3280
# Epoch 16/200
# 25/25 [==============================] - 0s 2ms/step - loss: 2.4657 - accuracy: 0.3440
# Epoch 17/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.4293 - accuracy: 0.4000
# Epoch 18/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3844 - accuracy: 0.3440
# Epoch 19/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3091 - accuracy: 0.3600
# Epoch 20/200
# 25/25 [==============================] - 0s 1ms/step - loss: 2.1389 - accuracy: 0.4160
# Epoch 21/200
# 25/25 [==============================] - 0s 2ms/step - loss: 2.0213 - accuracy: 0.4880
# Epoch 22/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.9349 - accuracy: 0.4960
# Epoch 23/200
# 25/25 [==============================] - 0s 2ms/step - loss: 1.8904 - accuracy: 0.4560
# Epoch 24/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7456 - accuracy: 0.5440
# Epoch 25/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7780 - accuracy: 0.4880
# Epoch 26/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7473 - accuracy: 0.5360
# Epoch 27/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.5685 - accuracy: 0.5840
# Epoch 28/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4442 - accuracy: 0.6000
# Epoch 29/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2778 - accuracy: 0.6800
# Epoch 30/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3424 - accuracy: 0.6400
# Epoch 31/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4287 - accuracy: 0.6080
# Epoch 32/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2408 - accuracy: 0.6480
# Epoch 33/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2257 - accuracy: 0.6240
# Epoch 34/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2974 - accuracy: 0.6160
# Epoch 35/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3407 - accuracy: 0.6080
# Epoch 36/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0059 - accuracy: 0.7040
# Epoch 37/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2427 - accuracy: 0.6080
# Epoch 38/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.9851 - accuracy: 0.7600
# Epoch 39/200
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0214 - accuracy: 0.7200
# Epoch 40/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.9060 - accuracy: 0.7360
# Epoch 41/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.8795 - accuracy: 0.7280
# Epoch 42/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.9406 - accuracy: 0.7200
# Epoch 43/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.9133 - accuracy: 0.6960
# Epoch 44/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7931 - accuracy: 0.7520
# Epoch 45/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6870 - accuracy: 0.8480
# Epoch 46/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.8091 - accuracy: 0.7440
# Epoch 47/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.8574 - accuracy: 0.7360
# Epoch 48/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7138 - accuracy: 0.7760
# Epoch 49/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.7600
# Epoch 50/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6533 - accuracy: 0.8000
# Epoch 51/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6508 - accuracy: 0.8400
# Epoch 52/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7056 - accuracy: 0.8160
# Epoch 53/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7569 - accuracy: 0.7600
# Epoch 54/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6422 - accuracy: 0.8080
# Epoch 55/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6298 - accuracy: 0.7920
# Epoch 56/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6599 - accuracy: 0.7920
# Epoch 57/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5738 - accuracy: 0.8400
# Epoch 58/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5212 - accuracy: 0.8560
# Epoch 59/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6637 - accuracy: 0.8000
# Epoch 60/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5391 - accuracy: 0.8080
# Epoch 61/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.9040
# Epoch 62/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5061 - accuracy: 0.8160
# Epoch 63/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.8800
# Epoch 64/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.9040
# Epoch 65/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4983 - accuracy: 0.8320
# Epoch 66/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5459 - accuracy: 0.8320
# Epoch 67/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5079 - accuracy: 0.8400
# Epoch 68/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.8880
# Epoch 69/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.8640
# Epoch 70/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.8640
# Epoch 71/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4021 - accuracy: 0.8640
# Epoch 72/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.8640
# Epoch 73/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5593 - accuracy: 0.8160
# Epoch 74/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.8640
# Epoch 75/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3772 - accuracy: 0.9040
# Epoch 76/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4406 - accuracy: 0.8000
# Epoch 77/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.8800
# Epoch 78/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3011 - accuracy: 0.9200
# Epoch 79/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.8320
# Epoch 80/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.8640
# Epoch 81/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.8560
# Epoch 82/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.9120
# Epoch 83/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.8800
# Epoch 84/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8960
# Epoch 85/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3606 - accuracy: 0.8640
# Epoch 86/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3955 - accuracy: 0.8800
# Epoch 87/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2992 - accuracy: 0.9120
# Epoch 88/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.8960
# Epoch 89/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3369 - accuracy: 0.9200
# Epoch 90/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3315 - accuracy: 0.9120
# Epoch 91/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3799 - accuracy: 0.8880
# Epoch 92/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3997 - accuracy: 0.8640
# Epoch 93/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2744 - accuracy: 0.9120
# Epoch 94/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.9280
# Epoch 95/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3926 - accuracy: 0.8960
# Epoch 96/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3880 - accuracy: 0.8800
# Epoch 97/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8880
# Epoch 98/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2766 - accuracy: 0.9040
# Epoch 99/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3422 - accuracy: 0.8800
# Epoch 100/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.8720
# Epoch 101/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2963 - accuracy: 0.9120
# Epoch 102/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2962 - accuracy: 0.8960
# Epoch 103/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3103 - accuracy: 0.9120
# Epoch 104/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3012 - accuracy: 0.8800
# Epoch 105/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2394 - accuracy: 0.9360
# Epoch 106/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2926 - accuracy: 0.8720
# Epoch 107/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4188 - accuracy: 0.8960
# Epoch 108/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3163 - accuracy: 0.9040
# Epoch 109/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3418 - accuracy: 0.8880
# Epoch 110/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9360
# Epoch 111/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2167 - accuracy: 0.9280
# Epoch 112/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9280
# Epoch 113/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3075 - accuracy: 0.8800
# Epoch 114/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2612 - accuracy: 0.9040
# Epoch 115/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2693 - accuracy: 0.9040
# Epoch 116/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2685 - accuracy: 0.9120
# Epoch 117/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9600
# Epoch 118/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2078 - accuracy: 0.9440
# Epoch 119/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2887 - accuracy: 0.8800
# Epoch 120/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3026 - accuracy: 0.9040
# Epoch 121/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3469 - accuracy: 0.8960
# Epoch 122/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3035 - accuracy: 0.9200
# Epoch 123/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3011 - accuracy: 0.8960
# Epoch 124/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3361 - accuracy: 0.8640
# Epoch 125/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1970 - accuracy: 0.9520
# Epoch 126/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4059 - accuracy: 0.8560
# Epoch 127/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2089 - accuracy: 0.9120
# Epoch 128/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.9120
# Epoch 129/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2413 - accuracy: 0.9120
# Epoch 130/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3414 - accuracy: 0.9120
# Epoch 131/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3726 - accuracy: 0.8560
# Epoch 132/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2746 - accuracy: 0.9360
# Epoch 133/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2270 - accuracy: 0.9200
# Epoch 134/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2522 - accuracy: 0.9360
# Epoch 135/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1684 - accuracy: 0.9360
# Epoch 136/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2175 - accuracy: 0.9360
# Epoch 137/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2799 - accuracy: 0.8880
# Epoch 138/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.9440
# Epoch 139/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1886 - accuracy: 0.9280
# Epoch 140/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.9280
# Epoch 141/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.9200
# Epoch 142/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1740 - accuracy: 0.9680
# Epoch 143/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9440
# Epoch 144/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2316 - accuracy: 0.9360
# Epoch 145/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 0.9360
# Epoch 146/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.9280
# Epoch 147/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3436 - accuracy: 0.8800
# Epoch 148/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.9440
# Epoch 149/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9280
# Epoch 150/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2161 - accuracy: 0.9440
# Epoch 151/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.9120
# Epoch 152/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1303 - accuracy: 0.9600
# Epoch 153/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.9360
# Epoch 154/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1566 - accuracy: 0.9520
# Epoch 155/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2284 - accuracy: 0.9440
# Epoch 156/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.9280
# Epoch 157/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2136 - accuracy: 0.9280
# Epoch 158/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9360
# Epoch 159/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1469 - accuracy: 0.9680
# Epoch 160/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9360
# Epoch 161/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1873 - accuracy: 0.9600
# Epoch 162/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2474 - accuracy: 0.9120
# Epoch 163/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2424 - accuracy: 0.9120
# Epoch 164/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2714 - accuracy: 0.8880
# Epoch 165/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1667 - accuracy: 0.9600
# Epoch 166/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9040
# Epoch 167/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1698 - accuracy: 0.9360
# Epoch 168/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1322 - accuracy: 0.9600
# Epoch 169/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2350 - accuracy: 0.9200
# Epoch 170/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2619 - accuracy: 0.9440
# Epoch 171/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2084 - accuracy: 0.9200
# Epoch 172/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.9200
# Epoch 173/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9600
# Epoch 174/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.9280
# Epoch 175/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.9040
# Epoch 176/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2091 - accuracy: 0.9120
# Epoch 177/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2066 - accuracy: 0.9360
# Epoch 178/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2107 - accuracy: 0.9520
# Epoch 179/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1291 - accuracy: 0.9600
# Epoch 180/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2181 - accuracy: 0.9200
# Epoch 181/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2382 - accuracy: 0.9120
# Epoch 182/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2934 - accuracy: 0.9360
# Epoch 183/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2305 - accuracy: 0.9200
# Epoch 184/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1463 - accuracy: 0.9760
# Epoch 185/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9520
# Epoch 186/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1364 - accuracy: 0.9440
# Epoch 187/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1715 - accuracy: 0.9360
# Epoch 188/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9200
# Epoch 189/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2852 - accuracy: 0.9200
# Epoch 190/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1695 - accuracy: 0.9440
# Epoch 191/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 0.9520
# Epoch 192/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1730 - accuracy: 0.9600
# Epoch 193/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9200
# Epoch 194/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1619 - accuracy: 0.9600
# Epoch 195/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.8960
# Epoch 196/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3373 - accuracy: 0.9200
# Epoch 197/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2454 - accuracy: 0.9440
# Epoch 198/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1986 - accuracy: 0.9520
# Epoch 199/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1322 - accuracy: 0.9520
# Epoch 200/200
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1970 - accuracy: 0.9280
# model created

# %%
from keras.models import load_model

model = load_model("../models/chatbot_model.h5")
import json
import random

intents = json.loads(open("../data/intents.json").read())
words = pickle.load(open("../models/words.pkl", "rb"))
classes = pickle.load(open("../models/classes.pkl", "rb"))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words


# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0] * len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print("found in bag: %s" % w)
    return np.array(bag)

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]["intent"]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result

# %%
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
import streamlit as st

# Function to send message


def send_message(input_message):
    msg = input_message.strip()
    if msg != "":
        st.write("You: " + msg)
        res = chatbot_response(msg)
        st.write("Bot: " + res)


# Define the layout of the Streamlit app


def main():
    st.title("Chat with Bot")
    input_message = st.text_input("Enter message:", "")
    if st.button("Send"):
        send_message(input_message)


# Run the Streamlit app
if __name__ == "__main__":
    main()
# Out:
# 2024-03-04 14:11:58.789
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\vinot\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
